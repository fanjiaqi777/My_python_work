# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import scienceplots
matplotlib.style.use(['science','notebook','grid','no-latex'])
plt.rcParams['font.family'] = 'Times New Roman'

# %%
import pandas as pd
file_name= 'E:/Python20230505/line-chart-SSC-CDQ.ric.csv'
data=pd.read_csv(file_name)
data
# Out:
#         MarkerID  LOD score-2022  PVE(%)-2022  EffectF-2022  EffectM-2022  \
# 0      01_326641          0.0788       0.1680        0.0685        0.0967
# 1     01_1728636          0.0447       0.0975        0.0142        0.0480
# 2     01_2171390          0.1601       0.3432        0.0056        0.0724
# 3     01_2316274          0.0123       0.0254        0.0185       -0.0306
# 4     01_2676393          0.1065       0.2307       -0.0445        0.0967
# ..           ...             ...          ...           ...           ...
# 476  08_20006712          0.4819       1.0520        0.1824       -0.1328
# 477  08_20565594          0.5372       1.1478        0.1443       -0.2022
# 478  08_21212690          0.5625       1.2050        0.1223       -0.2238
# 479  08_21292326          0.5628       1.2178        0.1195       -0.2320
# 480  08_21685180          0.5611       1.1963        0.1144       -0.2321
#
#      EffectFM-2022  Unnamed: 6   MarkerID.1  LOD score-2021  PVE(%)-2021  \
# ...

# %%
data_LOD=data[['MarkerID','LOD score-2022','LOD score-2021']]

# %%
data_LOD_X=data_LOD['MarkerID']
col_arrayX=data_LOD_X.to_numpy()
col_arrayX
# Out:
# array(['01_326641', '01_1728636', '01_2171390', '01_2316274',
#        '01_2676393', '01_3422639', '01_3841654', '01_4242882',
#        '01_4586681', '01_4805028', '01_5599710', '01_5930699',
#        '01_6386623', '01_6834348', '01_7054648', '01_7493326',
#        '01_7829979', '01_8040260', '01_8626458', '01_8919373',
#        '01_9021689', '01_9129962', '01_9475983', '01_9490599',
#        '01_10443078', '01_10753348', '01_10825401', '01_11268375',
#        '01_11519035', '01_11667221', '01_11963731', '01_12346900',
#        '01_12936448', '01_13748687', '01_14768029', '01_15978915',
#        '01_16823586', '01_16851551', '01_17192179', '01_17452216',
#        '01_17936195', '01_17967712', '01_19038584', '01_20300937',
#        '01_21501749', '01_21563516', '01_22081093', '01_22081093',
#        '01_22109794', '01_29509637', '01_29509637', '01_29509637',
#        '01_29509637', '01_29667385', '01_30474562', '01_30474562',
# ...

# %%
data_LOD_Y1=data_LOD['LOD score-2021']
col_arrayY1=data_LOD_Y1.to_numpy()
col_arrayY1
# Out:
# array([ 0.769 ,  0.6486,  1.2304,  0.3267,  0.7113,  0.7897,  0.4205,
#         0.6342,  0.5306,  0.7835,  1.1397,  0.9997,  0.9049,  1.3795,
#         0.476 ,  0.2943,  0.2281,  0.7214,  0.1227,  0.3268,  0.115 ,
#         0.23  ,  0.1318,  0.0435,  0.1337,  0.1848,  0.1083,  0.1915,
#         0.3377,  4.894 ,  4.8567,  4.8282,  4.2097,  6.7733,  7.2742,
#         7.1653,  4.7337,  4.6809,  4.2828,  0.374 ,  0.0428,  0.0989,
#         0.3506,  0.9605,  0.2157,  0.1892,  0.0775,  0.0224,  0.4181,
#         0.5388,  0.4577,  0.3831,  0.3427,  0.1566,  0.5726,  0.8233,
#         0.7477,  0.3677,  0.3898,  0.4105,  0.4281,  0.4562,  1.1056,
#         1.0686,  1.0001,  1.5668,  1.5213,  1.5028,  1.8212,  1.4005,
#         1.2961,  1.0443,  1.1488,  1.1506,  1.286 ,  1.2199,  1.091 ,
#         0.9589,  0.8078,  0.6964,  0.7232,  0.7385,  0.7417,  1.077 ,
#         0.7388,  0.5527,  0.431 ,  0.3255,  0.2769,  0.8301,  0.7266,
# ...

# %%
data_LOD_Y2=data_LOD['LOD score-2022']
col_arrayY2=data_LOD_Y2.to_numpy()
col_arrayY2
# Out:
# array([0.0788, 0.0447, 0.1601, 0.0123, 0.1065, 0.1985, 0.0117, 0.2405,
#        0.52  , 0.8667, 0.5145, 0.5604, 0.5632, 0.5251, 0.1744, 0.2592,
#        0.4271, 0.5584, 0.4249, 0.7436, 0.4941, 0.2215, 2.2442, 1.5154,
#        2.4495, 2.1876, 2.3212, 2.3684, 1.36  , 1.4058, 0.5596, 0.8017,
#        0.4225, 0.7294, 0.5728, 0.5022, 0.1789, 0.1012, 0.6629, 0.11  ,
#        0.1041, 0.2545, 0.1142, 1.091 , 0.098 , 0.2183, 0.1726, 0.4184,
#        0.0924, 0.3985, 0.3877, 0.3756, 0.3623, 0.2521, 0.2951, 0.3248,
#        0.5608, 0.8036, 0.792 , 0.7682, 0.7339, 0.6647, 0.4906, 0.5706,
#        0.9548, 0.8014, 0.8335, 0.9625, 0.9692, 0.8773, 1.0227, 0.7358,
#        0.7199, 1.1821, 1.3827, 1.242 , 1.1001, 1.1602, 1.2139, 1.2291,
#        1.1401, 1.0162, 0.8624, 0.8237, 1.4534, 1.4076, 1.1321, 1.888 ,
#        1.3418, 0.2637, 0.2504, 0.0721, 0.1802, 0.3995, 0.3213, 0.91  ,
#        0.427 , 0.3806, 0.402 , 0.3801, 0.3939, 0.3191, 1.5372, 1.2072,
# ...

# %%
data_PVE=data['PVE(%)-2022']

col_arrayPVE=data_PVE.to_numpy()
data_EffectFM=data['EffectFM-2022']
col_arrayEffectFM=data_EffectFM.to_numpy()
col_arrayEffectFM
# Out:
# array([-2.760e-02, -5.170e-02, -1.134e-01,  5.400e-03, -2.450e-02,
#        -1.158e-01, -3.000e-02, -6.060e-02, -1.955e-01, -2.996e-01,
#        -1.776e-01, -1.567e-01,  2.320e-02, -1.902e-01, -9.020e-02,
#        -1.505e-01, -7.560e-02, -1.344e-01, -1.571e-01, -2.671e-01,
#        -2.412e-01, -9.710e-02, -4.770e-02,  3.800e-02,  3.900e-03,
#        -4.990e-02, -6.590e-02,  1.420e-02, -5.600e-03,  3.030e-02,
#         1.202e-01,  1.206e-01, -1.150e-02,  1.407e-01,  1.840e-01,
#         1.331e-01, -6.270e-02, -2.970e-02, -7.240e-02, -4.090e-02,
#         7.970e-02,  1.873e-01,  1.343e-01,  3.492e-01,  1.223e-01,
#         5.840e-02,  6.060e-02,  2.375e-01,  8.500e-02, -1.850e-01,
#        -1.854e-01, -1.845e-01, -1.824e-01, -1.617e-01, -1.243e-01,
#        -1.507e-01, -2.309e-01, -3.267e-01, -3.257e-01, -3.184e-01,
#        -3.055e-01, -2.939e-01, -8.050e-02, -8.730e-02, -2.171e-01,
#        -1.236e-01, -1.920e-01, -2.510e-01, -2.861e-01, -2.723e-01,
# ...

# %%
col_arrayPVE
# Out:
# array([ 0.168 ,  0.0975,  0.3432,  0.0254,  0.2307,  0.4703,  0.0276,
#         0.5165,  1.1333,  1.8792,  1.0974,  1.2016,  1.2323,  1.1297,
#         0.3772,  0.5541,  0.9411,  1.1955,  0.9567,  1.6917,  1.1935,
#         0.4764,  5.1396,  3.5625,  5.5946,  4.9948,  5.4876,  5.394 ,
#         3.2808,  3.2599,  1.3105,  1.8797,  0.9021,  1.5552,  1.2414,
#         1.0743,  0.4647,  0.2285,  1.4136,  0.2368,  0.2324,  0.8456,
#         0.3246,  2.7353,  0.2683,  0.5444,  0.3967,  1.0938,  0.251 ,
#         0.8567,  0.838 ,  0.8116,  0.7779,  0.5628,  0.6324,  0.6948,
#         1.2189,  1.7187,  1.7374,  1.6919,  1.5905,  1.4434,  1.2412,
#         1.2183,  2.0441,  1.7028,  1.7864,  2.053 ,  2.1207,  1.8828,
#         2.2592,  1.6229,  1.5407,  2.5021,  2.9604,  2.6799,  2.3277,
#         2.5027,  2.6038,  2.6225,  2.5216,  2.2723,  1.8521,  1.7502,
#         3.2047,  3.0741,  2.5133,  4.0737,  3.1546,  0.7781,  0.5316,
# ...

# %%
fig,axes=plt.subplots(3,1,figsize=(20,9),dpi=300)

ax=axes[0]
ax.plot(col_arrayX,col_arrayY1,label='LOD_2021',c='orange')
ax.plot(col_arrayX,col_arrayY2,label='LOD_2022',c='dodgerblue')



ax.set_xticks([])
ax.grid (False) 
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='y', which='both',left=True, right=False)
ax.set_ylim((0, 14))
ax.fill_between(['01_326641','01_47186425'],0,14,facecolor = 'oldlace', alpha = 0.6)
ax.fill_between(['01_47186425','02_25313652'],0,14,facecolor = 'lightcyan', alpha = 0.6)
ax.fill_between(['02_25313652','03_27014719'],0,14,facecolor = 'oldlace', alpha = 0.6)
ax.fill_between(['03_27014719','04_820772'],0,14,facecolor = 'lightcyan', alpha = 0.6)
ax.fill_between(['04_820772','05_11943663'],0,14,facecolor = 'oldlace', alpha = 0.6)
ax.fill_between(['05_11943663','06_29609301'],0,14,facecolor = 'lightcyan', alpha = 0.6)
ax.fill_between(['06_29609301','07_22227171'],0,14,facecolor = 'oldlace', alpha = 0.6)
ax.fill_between(['07_22227171','08_21685180'],0,14,facecolor = 'lightcyan', alpha = 0.6)

ax.axhline(y = 3.5, color ="gray", linestyle ="--",lw=1.5,label="LOD_threshold")
ax.legend(loc='upper right',fontsize=13,ncol=1)
ax.text(30, -1.5, 'LG1', fontsize=14)
ax.text(95, -1.5, 'LG2', fontsize=14)
ax.text(135, -1.5, 'LG3', fontsize=14)
ax.text(190, -1.5, 'LG4', fontsize=14)
ax.text(230, -1.5, 'LG5', fontsize=14)
ax.text(280, -1.5, 'LG6', fontsize=14)
ax.text(340, -1.5, 'LG7', fontsize=14)
ax.text(390, -1.5, 'LG8', fontsize=14)

#only 图1
ax.fill_between(['04_5451407','04_820772'],3.5,10,facecolor = 'lightcyan', edgecolor='gray',linestyle="--",lw=1.5,alpha = 1)
ax.fill_between(['06_25707230','07_316408'],3.5,12,facecolor = 'lightcyan', edgecolor='gray',linestyle="--",lw=1.5,alpha = 1)
ax.text(208,10.7, 'qSG4', fontsize=15,fontstyle='italic')
ax.text(306,12.7, 'qSG6', fontsize=15,fontstyle='italic')
ax.set_ylabel('LOD score', fontsize=14)



ax=axes[1]
ax.plot(col_arrayX,col_arrayPVE,label='PVE',c='navy')
ax.grid (False) #取消网格
ax.set_xticks([])#取消x坐标轴坐标
ax.set_ylim(0, 20)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='y', which='both',left=True, right=False)
ax.legend(loc='upper right',fontsize=13,ncol=1)
ax.text(30, -2, 'LG1', fontsize=14)
ax.text(95, -2, 'LG2', fontsize=14)
ax.text(135, -2, 'LG3', fontsize=14)
ax.text(190, -2, 'LG4', fontsize=14)
ax.text(230, -2, 'LG5', fontsize=14)
ax.text(280, -2, 'LG6', fontsize=14)
ax.text(340, -2, 'LG7', fontsize=14)
ax.text(390, -2, 'LG8', fontsize=14)
ax.fill_between(['01_326641','01_47186425'],0,20,facecolor = 'oldlace', alpha = 0.6)
ax.fill_between(['01_47186425','02_25313652'],0,20,facecolor = 'lightcyan', alpha = 0.6)
ax.fill_between(['02_25313652','03_27014719'],0,20,facecolor = 'oldlace', alpha = 0.6)
ax.fill_between(['03_27014719','04_820772'],0,20,facecolor = 'lightcyan', alpha = 0.6)
ax.fill_between(['04_820772','05_11943663'],0,20,facecolor = 'oldlace', alpha = 0.6)
ax.fill_between(['05_11943663','06_29609301'],0,20,facecolor = 'lightcyan', alpha = 0.6)
ax.fill_between(['06_29609301','07_22227171'],0,20,facecolor = 'oldlace', alpha = 0.6)
ax.fill_between(['07_22227171','08_21685180'],0,20,facecolor = 'lightcyan', alpha = 0.6)


ax.fill_between(col_arrayX, 0, col_arrayPVE, facecolor='mediumblue', alpha=0.6)

ax.set_ylabel('PVE %', fontsize=14)
ax=axes[2]

ax.plot(col_arrayX,col_arrayEffectFM,label='Additive_Effect',c='palevioletred')
ax.grid (False) #取消网格
ax.set_xticks([])#取消x坐标轴坐标
ax.set_ylim(-0.8, 0.6)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='y', which='both',left=True, right=False)
ax.legend(loc='upper right',fontsize=13,ncol=1)

ax.text(30, -0.96, 'LG1', fontsize=14)
ax.text(95, -0.96, 'LG2', fontsize=14)
ax.text(135, -0.96, 'LG3', fontsize=14)
ax.text(190, -0.96, 'LG4', fontsize=14)
ax.text(230, -0.96, 'LG5', fontsize=14)
ax.text(280, -0.96, 'LG6', fontsize=14)
ax.text(340, -0.96, 'LG7', fontsize=14)
ax.text(390, -0.96, 'LG8', fontsize=14)
ax.fill_between(['01_326641','01_47186425'],-0.8,0.6,facecolor = 'oldlace', alpha = 0.6)
ax.fill_between(['01_47186425','02_25313652'],-0.8,0.6,facecolor = 'lightcyan', alpha = 0.6)
ax.fill_between(['02_25313652','03_27014719'],-0.8,0.6,facecolor = 'oldlace', alpha = 0.6)
ax.fill_between(['03_27014719','04_820772'],-0.8,0.6,facecolor = 'lightcyan', alpha = 0.6)
ax.fill_between(['04_820772','05_11943663'],-0.8,0.6,facecolor = 'oldlace', alpha = 0.6)
ax.fill_between(['05_11943663','06_29609301'],-0.8,0.6,facecolor = 'lightcyan', alpha = 0.6)
ax.fill_between(['06_29609301','07_22227171'],-0.8,0.6,facecolor = 'oldlace', alpha = 0.6)
ax.fill_between(['07_22227171','08_21685180'],-0.8,0.6,facecolor = 'lightcyan', alpha = 0.6)
ax.axhline(y = 0, color ="k", linestyle ="-",lw=1.5)
ax.set_ylabel('Effect', fontsize=14)

plt.savefig("SSC_20230512-1.pdf",bbox_inches='tight')

# %%
fig, axes = plt.subplots(3, 1, figsize=(20, 9), dpi=300, sharex=True, gridspec_kw={'hspace': 0.5})
# First subplot
ax = axes[0]
ax.plot(col_arrayX, col_arrayY1, label='LOD_2021', c='tab:orange', lw=2)
ax.plot(col_arrayX, col_arrayY2, label='LOD_2022', c='tab:blue', lw=2)

ax.set_xticks([])
ax.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='y', which='both', left=True, right=False, labelsize=12)
ax.set_ylim((0, 14))
ax.fill_between(['01_326641', '01_47186425'], 0, 14, facecolor='lightgray', alpha=0.6)
ax.fill_between(['01_47186425', '02_25313652'], 0, 14, facecolor='darkgray', alpha=0.6)
ax.fill_between(['02_25313652', '03_27014719'], 0, 14, facecolor='lightgray', alpha=0.6)
ax.fill_between(['03_27014719', '04_820772'], 0, 14, facecolor='darkgray', alpha=0.6)
ax.fill_between(['04_820772', '05_11943663'], 0, 14, facecolor='lightgray', alpha=0.6)
ax.fill_between(['05_11943663', '06_29609301'], 0, 14, facecolor='darkgray', alpha=0.6)
ax.fill_between(['06_29609301', '07_22227171'], 0, 14, facecolor='lightgray', alpha=0.6)
ax.fill_between(['07_22227171', '08_21685180'], 0, 14, facecolor='darkgray', alpha=0.6)

ax.axhline(y=3.5, color="gray", linestyle="--", lw=1.5, label="LOD_threshold")
ax.legend(loc='upper right', fontsize=13, ncol=1)
ax.text(30, -1.5, 'LG1', fontsize=14)
ax.text(95, -1.5, 'LG2', fontsize=14)
ax.text(135, -1.5, 'LG3', fontsize=14)
ax.text(190, -1.5, 'LG4', fontsize=14)
ax.text(230, -1.5, 'LG5', fontsize=14)
ax.text(280, -1.5, 'LG6', fontsize=14)
ax.text(340, -1.5, 'LG7', fontsize=14)
ax.text(390, -1.5, 'LG8', fontsize=14)
ax.fill_between(['04_5451407', '04_820772'], 3.5, 10, facecolor='lightgray', edgecolor='gray', linestyle="--", lw=1.5, alpha=1)
ax.fill_between(['06_25707230', '07_316408'], 3.5, 12, facecolor='lightgray', edgecolor='gray', linestyle="--", lw=1.5, alpha=1)
ax.text(208, 10.7, 'qSG4', fontsize=15, fontstyle='italic')
ax.text(306, 12.7, 'qSG6', fontsize=15, fontstyle='italic')
ax.set_ylabel('LOD score', fontsize=14)
ax.set_title('LOD Scores for 2021 and 2022', fontsize=16)

# Second subplot
ax = axes[1]
ax.plot(col_arrayX, col_arrayPVE, label='PVE', c='tab:green', lw=2)
ax.grid(False)
ax.set_xticks([])
ax.set_ylim(0, 20)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='y', which='both', left=True, right=False, labelsize=12)
ax.legend(loc='upper right', fontsize=13, ncol=1)
ax.text(30, -2.5, 'LG1', fontsize=14)
ax.text(95, -2.5, 'LG2', fontsize=14)
ax.text(135, -2.5, 'LG3', fontsize=14)
ax.text(190, -2.5, 'LG4', fontsize=14)
ax.text(230, -2.5, 'LG5', fontsize=14)
ax.text(280, -2.5, 'LG6', fontsize=14)
ax.text(340, -2.5, 'LG7', fontsize=14)
ax.text(390, -2.5, 'LG8', fontsize=14)
ax.fill_between(['01_326641', '01_47186425'], 0, 20, facecolor='lightgray', alpha=0.6)
ax.fill_between(['01_47186425', '02_25313652'], 0, 20, facecolor='darkgray', alpha=0.6)
ax.fill_between(['02_25313652', '03_27014719'], 0, 20, facecolor='lightgray', alpha=0.6)
ax.fill_between(['03_27014719', '04_820772'], 0, 20, facecolor='darkgray', alpha=0.6)
ax.fill_between(['04_820772', '05_11943663'], 0, 20, facecolor='lightgray', alpha=0.6)
ax.fill_between(['05_11943663', '06_29609301'], 0, 20, facecolor='darkgray', alpha=0.6)
ax.fill_between(['06_29609301', '07_22227171'], 0, 20, facecolor='lightgray', alpha=0.6)
ax.fill_between(['07_22227171', '08_21685180'], 0, 20, facecolor='darkgray', alpha=0.6)

ax.fill_between(col_arrayX, 0, col_arrayPVE, facecolor='tab:green', alpha=0.6)

ax.set_ylabel('PVE %', fontsize=14)
ax.set_title('Percentage of Variance Explained', fontsize=16)

# Third subplot
ax = axes[2]
ax.plot(col_arrayX, col_arrayEffectFM, label='Additive_Effect', c='tab:red', lw=2)
ax.grid(False)
ax.set_xticks([])
ax.set_ylim(-0.8, 0.6)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='y', which='both', left=True, right=False, labelsize=12)
ax.legend(loc='upper right', fontsize=13, ncol=1)

ax.text(30, -0.96, 'LG1', fontsize=14)
ax.text(95, -0.96, 'LG2', fontsize=14)
ax.text(135, -0.96, 'LG3', fontsize=14)
ax.text(190, -0.96, 'LG4', fontsize=14)
ax.text(230, -0.96, 'LG5', fontsize=14)
ax.text(280, -0.96, 'LG6', fontsize=14)
ax.text(340, -0.96, 'LG7', fontsize=14)
ax.text(390, -0.96, 'LG8', fontsize=14)
ax.fill_between(['01_326641','01_47186425'],-0.8,0.6,facecolor = 'lightgray', alpha = 0.6)
ax.fill_between(['01_47186425','02_25313652'],-0.8,0.6,facecolor = 'darkgray', alpha = 0.6)
ax.fill_between(['02_25313652','03_27014719'],-0.8,0.6,facecolor = 'lightgray', alpha = 0.6)
ax.fill_between(['03_27014719','04_820772'],-0.8,0.6,facecolor = 'darkgray', alpha = 0.6)
ax.fill_between(['04_820772','05_11943663'],-0.8,0.6,facecolor = 'lightgray', alpha = 0.6)
ax.fill_between(['05_11943663','06_29609301'],-0.8,0.6,facecolor = 'darkgray', alpha = 0.6)
ax.fill_between(['06_29609301','07_22227171'],-0.8,0.6,facecolor = 'lightgray', alpha = 0.6)
ax.fill_between(['07_22227171','08_21685180'],-0.8,0.6,facecolor = 'darkgray', alpha = 0.6)
ax.axhline(y = 0, color ="k", linestyle ="-",lw=1.5)
ax.set_ylabel('Effect', fontsize=14)
ax.set_title('Additive Effect', fontsize=16)
plt.savefig("SSC_20230512-2.pdf",bbox_inches='tight')
