# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import scienceplots
matplotlib.style.use(['science','notebook','grid','no-latex'])
plt.rcParams['font.family'] = 'Times New Roman'
import pandas as pd
file_name= 'E:/Python20230505/色卡等级的几个基因-3.csv'
data=pd.read_csv(file_name)
data
# Out:
#   Unnamed: 0  Prupe.4G170600-Female  Prupe.4G170600-Male  Unnamed: 3  \
# 0     stage1                  1.000                 1.11         NaN
# 1     stage2                  0.686                 1.02         NaN
# 2     stage3                  0.874                 1.22         NaN
# 3     stage4                  1.780                 1.40         NaN
# 4     stage5                  1.170                 1.61         NaN
#
#    Prupe.4G171100-Female  Prupe.4G171100-Male  Unnamed: 6  \
# 0                  1.000                1.520         NaN
# 1                  2.150                0.966         NaN
# 2                  0.986                1.240         NaN
# 3                  0.539                3.240         NaN
# 4                  1.100                0.974         NaN
#
#    Prupe.4G176200-Female  Prupe.4G176200-Female.1  Unnamed: 9  ...  \
# 0                   1.00                     3.53         NaN  ...
# ...

# %%
A1=data[['Unnamed: 0','Prupe.4G170600-Female','Prupe.4G170600-Male']]
A1
# Out:
#   Unnamed: 0  Prupe.4G170600-Female  Prupe.4G170600-Male
# 0     stage1                  1.000                 1.11
# 1     stage2                  0.686                 1.02
# 2     stage3                  0.874                 1.22
# 3     stage4                  1.780                 1.40
# 4     stage5                  1.170                 1.61

# %%
A2=data[['Unnamed: 0','Prupe.4G176200-Female','Prupe.4G176200-Female.1']]
A2
# Out:
#   Unnamed: 0  Prupe.4G171100-Female  Prupe.4G171100-Male
# 0     stage1                  1.000                1.520
# 1     stage2                  2.150                0.966
# 2     stage3                  0.986                1.240
# 3     stage4                  0.539                3.240
# 4     stage5                  1.100                0.974

# %%
A3=data[['Unnamed: 0','Prupe.4G176200-Female','Prupe.4G176200-Female.1']]
A3
# Out:
#   Unnamed: 0  Prupe.4G176200-Female  Prupe.4G176200-Female.1
# 0     stage1                   1.00                     3.53
# 1     stage2                   4.41                     2.00
# 2     stage3                   9.11                     2.26
# 3     stage4                   2.14                     3.12
# 4     stage5                   3.05                     3.56

# %%
A4=data[['Unnamed: 0','Prupe.4G187100-Female','Prupe.4G176900-Male']]
A4
# Out:
#   Unnamed: 0  Prupe.4G176900-Female  Prupe.4G176900-Male
# 0     stage1                  1.000                0.983
# 1     stage2                  0.865                0.624
# 2     stage3                  0.659                0.595
# 3     stage4                  0.236                0.446
# 4     stage5                  0.304                0.466

# %%
A5=data[['Unnamed: 0','Prupe.4G187100-Female','Prupe.4G187100-Male']]
A5
# Out:
#   Unnamed: 0  Prupe.4G187100-Female  Prupe.4G187100-Male
# 0     stage1                  1.000                0.968
# 1     stage2                  0.879                0.653
# 2     stage3                  0.808                0.588
# 3     stage4                  0.835                1.010
# 4     stage5                  1.200                0.577

# %%
A6=data[['Unnamed: 0','Prupe.4G182100-Female','Prupe.4G182100-Male']]
A6
# Out:
#   Unnamed: 0  Prupe.4G182100-Female  Prupe.4G182100-Male
# 0     stage1                   1.00                 4.91
# 1     stage2                  10.30                11.40
# 2     stage3                   8.66                 7.78
# 3     stage4                   5.19                 8.31
# 4     stage5                   5.24                 5.11

# %%
A7=data[['Unnamed: 0','Prupe.4G185800-Female','Prupe.4G185800-Male']]
A7
# Out:
#   Unnamed: 0  Prupe.4G185800-Female  Prupe.4G185800-Male
# 0     stage1                   1.00                 2.10
# 1     stage2                   1.23                 1.43
# 2     stage3                   4.28                 2.22
# 3     stage4                   5.02                 2.23
# 4     stage5                   5.57                 2.58

# %%
A8=data[['Unnamed: 0','Prupe.4G200500-Female','Prupe.4G200500-Male']]
A8
# Out:
#   Unnamed: 0  Prupe.4G200500-Female  Prupe.4G200500-Male
# 0     stage1                   1.00                 1.61
# 1     stage2                   1.41                 1.73
# 2     stage3                   2.58                 9.43
# 3     stage4                  10.40                 4.95
# 4     stage5                   4.81                 6.39

# %%
import matplotlib.patches as mpatches
fig, axes = plt.subplots(2, 4, figsize=(20, 9), dpi=300, sharex=True, gridspec_kw={'hspace': 0.5})

ax1=axes[0,0]
bar_width = 0.25
yerr1_1=[0.1,0.1,0.03,0.3,0.2]
yerr1_2=[0.1,0.1,0.1,0.05,0.3]
ax1.bar(np.arange(len(A1)), A1['Prupe.4G170600-Female'], yerr=yerr1_1, capsize=3, label='Female', color='steelblue',
        alpha=0.8, width=bar_width)
ax1.bar(np.arange(len(A1))+bar_width, A1['Prupe.4G170600-Male'], yerr=yerr1_2, capsize=3, label='Male', color='indianred',
        alpha=0.8, width=bar_width)

ax1.spines['right'].set_visible(False)  
ax1.spines['top'].set_visible(False)
ax1.xaxis.set_ticks_position('bottom')#将坐标轴固定在某一端
ax1.yaxis.set_ticks_position('left')#将坐标轴固定在某一端

ax1.set_xticks(np.arange(len(A1)) + bar_width/2)
ax1.set_xticklabels(A1['Unnamed: 0'])
#ax1.set_xlabel('Fruit Developmental Stages')
ax1.set_ylabel('Relative expression')
ax1.set_title('Prupe.4G200500')

ax1.legend().remove()

ax2=axes[0,1]
bar_width = 0.25
yerr2_1=[0.1,0.2,0.03,0.3,0.2]
yerr2_2=[0.1,0.13,0.1,0.09,0.3]

ax2.bar(np.arange(len(A2)), A2['Prupe.4G171100-Female'], yerr=yerr2_1, capsize=3, label='Female', color='steelblue',
        alpha=0.8, width=bar_width)
ax2.bar(np.arange(len(A2))+bar_width, A2['Prupe.4G171100-Male'], yerr=yerr2_2, capsize=3, label='Male', color='indianred',
        alpha=0.8, width=bar_width)

ax2.spines['right'].set_visible(False)  
ax2.spines['top'].set_visible(False)
ax2.xaxis.set_ticks_position('bottom')#将坐标轴固定在某一端
ax2.yaxis.set_ticks_position('left')#将坐标轴固定在某一端

ax2.set_xticks(np.arange(len(A2)) + bar_width/2)
ax2.set_xticklabels(A2['Unnamed: 0'])
#ax2.set_xlabel('Fruit Developmental Stages')
ax2.set_ylabel('Relative expression')
ax2.set_title('Prupe.4G171100')

ax2.legend().remove()


ax3=axes[0,2]

yerr3_1=[0.1,0.3,0.7,0.3,0.2]
yerr3_2=[0.1,0.13,0.1,0.09,0.3]

ax3.bar(np.arange(len(A3)), A3['Prupe.4G176200-Female'], yerr=yerr3_1, capsize=3, label='Female', color='steelblue',
        alpha=0.8, width=bar_width)
ax3.bar(np.arange(len(A3))+bar_width, A3['Prupe.4G176200-Female.1'], yerr=yerr3_2, capsize=3, label='Male', color='indianred',
        alpha=0.8, width=bar_width)

ax3.spines['right'].set_visible(False)  
ax3.spines['top'].set_visible(False)
ax3.xaxis.set_ticks_position('bottom')#将坐标轴固定在某一端
ax3.yaxis.set_ticks_position('left')#将坐标轴固定在某一端

ax3.set_xticks(np.arange(len(A3)) + bar_width/2)
ax3.set_xticklabels(A3['Unnamed: 0'])
#ax3.set_xlabel('Fruit Developmental Stages')
ax3.set_ylabel('Relative expression')
ax3.set_title('Prupe.4G176200')

ax3.legend().remove()

ax4=axes[0,3]

yerr4_1=[0.04,0.09,0.03,0.04,0.02]
yerr4_2=[0.06,0.1,0.021,0.09,0.03]

ax4.bar(np.arange(len(A4)), A4['Prupe.4G176900-Female'], yerr=yerr4_1, capsize=3, label='Female', color='steelblue',
        alpha=0.8, width=bar_width)
ax4.bar(np.arange(len(A4))+bar_width, A4['Prupe.4G176900-Male'], yerr=yerr4_2, capsize=3, label='Male', color='indianred',
        alpha=0.8, width=bar_width)

ax4.spines['right'].set_visible(False)  
ax4.spines['top'].set_visible(False)
ax4.xaxis.set_ticks_position('bottom')#将坐标轴固定在某一端
ax4.yaxis.set_ticks_position('left')#将坐标轴固定在某一端

ax4.set_xticks(np.arange(len(A4)) + bar_width/2)
ax4.set_xticklabels(A4['Unnamed: 0'])
#ax4.set_xlabel('Fruit Developmental Stages')
ax4.set_ylabel('Relative expression')
ax4.set_title('Prupe.4G176900')

ax4.legend().remove()

ax5=axes[1,0]

yerr5_1=[0.04,0.09,0.03,0.04,0.11]
yerr5_2=[0.06,0.1,0.021,0.09,0.1]

ax5.bar(np.arange(len(A5)), A5['Prupe.4G187100-Female'], yerr=yerr5_1, capsize=3, label='Female', color='steelblue',
        alpha=0.8, width=bar_width)
ax5.bar(np.arange(len(A5))+bar_width, A5['Prupe.4G187100-Male'], yerr=yerr5_2, capsize=3, label='Male', color='indianred',
        alpha=0.8, width=bar_width)

ax5.spines['right'].set_visible(False)  
ax5.spines['top'].set_visible(False)
ax5.xaxis.set_ticks_position('bottom')#将坐标轴固定在某一端
ax5.yaxis.set_ticks_position('left')#将坐标轴固定在某一端

ax5.set_xticks(np.arange(len(A5)) + bar_width/2)
ax5.set_xticklabels(A5['Unnamed: 0'])
#ax5.set_xlabel('Fruit Developmental Stages')
ax5.set_ylabel('Relative expression')
ax5.set_title('Prupe.4G187100')

ax5.legend().remove()

ax6=axes[1,1]

yerr6_1=[0.04,0.1,0.23,0.54,0.7]
yerr6_2=[1,0.2,0.5,0.9,0.9]

ax6.bar(np.arange(len(A6)), A6['Prupe.4G182100-Female'], yerr=yerr6_1, capsize=3, label='Female', color='steelblue',
        alpha=0.8, width=bar_width)
ax6.bar(np.arange(len(A6))+bar_width, A6['Prupe.4G182100-Male'], yerr=yerr6_2, capsize=3, label='Male', color='indianred',
        alpha=0.8, width=bar_width)

ax6.spines['right'].set_visible(False)  
ax6.spines['top'].set_visible(False)
ax6.xaxis.set_ticks_position('bottom')#将坐标轴固定在某一端
ax6.yaxis.set_ticks_position('left')#将坐标轴固定在某一端

ax6.set_xticks(np.arange(len(A6)) + bar_width/2)
ax6.set_xticklabels(A6['Unnamed: 0'])
#ax6.set_xlabel('Fruit Developmental Stages')
ax6.set_ylabel('Relative expression')
ax6.set_title('Prupe.4G182100')

ax6.legend().remove()

ax7=axes[1,2]

yerr7_1=[0.01,0.1,0.23,0.54,0.7]
yerr7_2=[0.1,0.2,0.1,0.09,0.09]

ax7.bar(np.arange(len(A7)), A7['Prupe.4G185800-Female'], yerr=yerr7_1, capsize=3, label='Female', color='steelblue',
        alpha=0.8, width=bar_width)
ax7.bar(np.arange(len(A7))+bar_width, A7['Prupe.4G185800-Male'], yerr=yerr7_2, capsize=3, label='Male', color='indianred',
        alpha=0.8, width=bar_width)

ax7.spines['right'].set_visible(False)  
ax7.spines['top'].set_visible(False)
ax7.xaxis.set_ticks_position('bottom')#将坐标轴固定在某一端
ax7.yaxis.set_ticks_position('left')#将坐标轴固定在某一端

ax7.set_xticks(np.arange(len(A7)) + bar_width/2)
ax7.set_xticklabels(A7['Unnamed: 0'])
#ax7.set_xlabel('Fruit Developmental Stages')
ax7.set_ylabel('Relative expression')
ax7.set_title('Prupe.4G185800')

ax7.legend().remove()

ax8=axes[1,3]

yerr8_1=[0.01,0.4,0.33,0.54,0.7]
yerr8_2=[0.1,0.2,0.7,1,0.9]

ax8.bar(np.arange(len(A8)), A8['Prupe.4G200500-Female'], yerr=yerr8_1, capsize=3, label='Female', color='steelblue',
        alpha=0.8, width=bar_width)
ax8.bar(np.arange(len(A8))+bar_width, A8['Prupe.4G200500-Male'], yerr=yerr8_2, capsize=3, label='Male', color='indianred',
        alpha=0.8, width=bar_width)

ax8.spines['right'].set_visible(False)  
ax8.spines['top'].set_visible(False)
ax8.xaxis.set_ticks_position('bottom')#将坐标轴固定在某一端
ax8.yaxis.set_ticks_position('left')#将坐标轴固定在某一端

ax8.set_xticks(np.arange(len(A8)) + bar_width/2)
ax8.set_xticklabels(A8['Unnamed: 0'])
#ax8.set_xlabel('Fruit Developmental Stages')
ax8.set_ylabel('Relative expression')
ax8.set_title('Prupe.4G200500')
ax8.legend().remove()

#mpatches 是Python中matplotlib库中的一个模块，
#提供了各种用于绘制图形的补丁（patch），例如矩形、圆、多边形等。
#而mpatches.Patch则是该模块所提供的一个基类，用于定义各种不同类型补丁共享的基本属性和方法。
fig.legend(handles=[mpatches.Patch(color='steelblue', alpha=0.8),
                     mpatches.Patch(color='indianred', alpha=0.8)],
           labels=['Zhongyoupan#9', 'SeptemberFree'], loc='upper right', ncol=1)
plt.savefig("Relative expression-20230531.pdf",bbox_inches='tight')
