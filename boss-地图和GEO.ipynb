# %%
from pyecharts.charts import Geo

data = [
    ("海门", 9),("鄂尔多斯", 12),("招远", 12),("舟山", 12),("齐齐哈尔", 14),("盐城", 15),
    ("赤峰", 16),("青岛", 18),("乳山", 18),("金昌", 19),("泉州", 21),("莱西", 21),
    ("日照", 21),("胶南", 22),("南通", 23),("拉萨", 24),("云浮", 24),("梅州", 25),
    ("文登", 25),("上海", 25),("攀枝花", 25),("威海", 25),("承德", 25),("厦门", 26),
    ("汕尾", 26),("潮州", 26),("丹东", 27),("太仓", 27),("曲靖", 27),("烟台", 28),
    ("福州", 29),("瓦房店", 30),("即墨", 30),("抚顺", 31),("玉溪", 31),("张家口", 31),
    ("阳泉", 31),("莱州", 32),("湖州", 32),("汕头", 32),("昆山", 33),("宁波", 33),
    ("湛江", 33),("揭阳", 34),("荣成", 34),("连云港", 35),("葫芦岛", 35),("常熟", 36),
    ("东莞", 36),("河源", 36),("淮安", 36),("泰州", 36),("南宁", 37),("营口", 37),
    ("惠州", 37),("江阴", 37),("蓬莱", 37),("韶关", 38),("嘉峪关", 38),("广州", 38),
    ("延安", 38),("太原", 39),("清远", 39),("中山", 39),("昆明", 39),("寿光", 40),
    ("盘锦", 40),("长治", 41),("深圳", 41),("珠海", 42),("宿迁", 43),("咸阳", 43),
    ("铜川", 44),("平度", 44),("佛山", 44),("海口", 44),("江门", 45),("章丘", 45),
    ("肇庆", 46),("大连", 47),("临汾", 47),("吴江", 47),("石嘴山", 49),("沈阳", 50),
    ("苏州", 50),("茂名", 50),("嘉兴", 51),("长春", 51),("胶州", 52),("银川", 52),
    ("张家港", 52),("三门峡", 53),("锦州", 54),("南昌", 54),("柳州", 54),("三亚", 54),
    ("自贡", 56),("吉林", 56),("阳江", 57),("泸州", 57),("西宁", 57),("宜宾", 58),
    ("呼和浩特", 58),("成都", 58),("大同", 58),("镇江", 59),("桂林", 59),("张家界", 59),
    ("宜兴", 59),("北海", 60),("西安", 61),("金坛", 62),("东营", 62),("牡丹江", 63),
    ("遵义", 63),("绍兴", 63),("扬州", 64),("常州", 64),("潍坊", 65),("重庆", 66),
    ("台州", 67),("南京", 67),("滨州", 70),("贵阳", 71),("无锡", 71),("本溪", 71),
    ("克拉玛依", 72),("渭南", 72),("马鞍山", 72),("宝鸡", 72),("焦作", 75),("句容", 75),
    ("北京", 79),("徐州", 79),("衡水", 80),("包头", 80),("绵阳", 80),("乌鲁木齐", 84),
    ("枣庄", 84),("杭州", 84),("淄博", 85),("鞍山", 86),("溧阳", 86),("库尔勒", 86),
    ("安阳", 90),("开封", 90),("济南", 92),("德阳", 93),("温州", 95),("九江", 96),
    ("邯郸", 98),("临安", 99),("兰州", 99),("沧州", 100),("临沂", 103),("南充", 104),
    ("天津", 105),("富阳", 106),("泰安", 112),("诸暨", 112),("郑州", 113),("哈尔滨", 114),
    ("聊城", 116),("芜湖", 117),("唐山", 119),("平顶山", 119),("邢台", 119),("德州", 120),
    ("济宁", 120),("荆州", 127),("宜昌", 130),("义乌", 132),("丽水", 133),("洛阳", 134),
    ("秦皇岛", 136),("株洲", 143),("石家庄", 147),("莱芜", 148),("常德", 152),("保定", 153),
    ("湘潭", 154),("金华", 157),("岳阳", 169),("长沙", 175),("衢州", 177),("廊坊", 193),
    ("菏泽", 194),("合肥", 229),("武汉", 273),("大庆", 279)]

geo = Geo(
    "全国主要城市空气质量",
    "data from pm2.5",
    title_color="#fff",
    title_pos="center",
    width=1200,
    height=600,
    background_color="#404a59",
)
attr, value = geo.cast(data)
geo.add(
    "",
    attr,
    value,
    visual_range=[0, 200],
    visual_text_color="#fff",
    symbol_size=15,
    is_visualmap=True,
)
geo.render()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15616/3720753786.py in <module>
#      35     ("菏泽", 194),("合肥", 229),("武汉", 273),("大庆", 279)]
#      36
# ---> 37 geo = Geo(
#      38     "全国主要城市空气质量",
#      39     "data from pm2.5",
#
# TypeError: __init__() got an unexpected keyword argument 'title_color'

# %%
pip uninstall pyecharts
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall pyecharts --yes
# Out:
# Found existing installation: pyecharts 2.0.3
# Uninstalling pyecharts-2.0.3:
#   Successfully uninstalled pyecharts-2.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyecharts import Geo

data = [
    ("海门", 9),("鄂尔多斯", 12),("招远", 12),("舟山", 12),("齐齐哈尔", 14),("盐城", 15),
    ("赤峰", 16),("青岛", 18),("乳山", 18),("金昌", 19),("泉州", 21),("莱西", 21),
    ("日照", 21),("胶南", 22),("南通", 23),("拉萨", 24),("云浮", 24),("梅州", 25),
    ("文登", 25),("上海", 25),("攀枝花", 25),("威海", 25),("承德", 25),("厦门", 26),
    ("汕尾", 26),("潮州", 26),("丹东", 27),("太仓", 27),("曲靖", 27),("烟台", 28),
    ("福州", 29),("瓦房店", 30),("即墨", 30),("抚顺", 31),("玉溪", 31),("张家口", 31),
    ("阳泉", 31),("莱州", 32),("湖州", 32),("汕头", 32),("昆山", 33),("宁波", 33),
    ("湛江", 33),("揭阳", 34),("荣成", 34),("连云港", 35),("葫芦岛", 35),("常熟", 36),
    ("东莞", 36),("河源", 36),("淮安", 36),("泰州", 36),("南宁", 37),("营口", 37),
    ("惠州", 37),("江阴", 37),("蓬莱", 37),("韶关", 38),("嘉峪关", 38),("广州", 38),
    ("延安", 38),("太原", 39),("清远", 39),("中山", 39),("昆明", 39),("寿光", 40),
    ("盘锦", 40),("长治", 41),("深圳", 41),("珠海", 42),("宿迁", 43),("咸阳", 43),
    ("铜川", 44),("平度", 44),("佛山", 44),("海口", 44),("江门", 45),("章丘", 45),
    ("肇庆", 46),("大连", 47),("临汾", 47),("吴江", 47),("石嘴山", 49),("沈阳", 50),
    ("苏州", 50),("茂名", 50),("嘉兴", 51),("长春", 51),("胶州", 52),("银川", 52),
    ("张家港", 52),("三门峡", 53),("锦州", 54),("南昌", 54),("柳州", 54),("三亚", 54),
    ("自贡", 56),("吉林", 56),("阳江", 57),("泸州", 57),("西宁", 57),("宜宾", 58),
    ("呼和浩特", 58),("成都", 58),("大同", 58),("镇江", 59),("桂林", 59),("张家界", 59),
    ("宜兴", 59),("北海", 60),("西安", 61),("金坛", 62),("东营", 62),("牡丹江", 63),
    ("遵义", 63),("绍兴", 63),("扬州", 64),("常州", 64),("潍坊", 65),("重庆", 66),
    ("台州", 67),("南京", 67),("滨州", 70),("贵阳", 71),("无锡", 71),("本溪", 71),
    ("克拉玛依", 72),("渭南", 72),("马鞍山", 72),("宝鸡", 72),("焦作", 75),("句容", 75),
    ("北京", 79),("徐州", 79),("衡水", 80),("包头", 80),("绵阳", 80),("乌鲁木齐", 84),
    ("枣庄", 84),("杭州", 84),("淄博", 85),("鞍山", 86),("溧阳", 86),("库尔勒", 86),
    ("安阳", 90),("开封", 90),("济南", 92),("德阳", 93),("温州", 95),("九江", 96),
    ("邯郸", 98),("临安", 99),("兰州", 99),("沧州", 100),("临沂", 103),("南充", 104),
    ("天津", 105),("富阳", 106),("泰安", 112),("诸暨", 112),("郑州", 113),("哈尔滨", 114),
    ("聊城", 116),("芜湖", 117),("唐山", 119),("平顶山", 119),("邢台", 119),("德州", 120),
    ("济宁", 120),("荆州", 127),("宜昌", 130),("义乌", 132),("丽水", 133),("洛阳", 134),
    ("秦皇岛", 136),("株洲", 143),("石家庄", 147),("莱芜", 148),("常德", 152),("保定", 153),
    ("湘潭", 154),("金华", 157),("岳阳", 169),("长沙", 175),("衢州", 177),("廊坊", 193),
    ("菏泽", 194),("合肥", 229),("武汉", 273),("大庆", 279)]

geo = Geo(
    "全国主要城市空气质量",
    "data from pm2.5",
    title_color="#fff",
    title_pos="center",
    width=1200,
    height=600,
    background_color="#404a59",
)
attr, value = geo.cast(data)
geo.add(
    "",
    attr,
    value,
    visual_range=[0, 200],
    visual_text_color="#fff",
    symbol_size=15,
    is_visualmap=True,
)
geo.render()

# %%
pip install echarts-cities-pypkg
# Out:
# ...
#   Created wheel for echarts-cities-pypkg: filename=echarts_cities_pypkg-0.0.1-py3-none-any.whl size=1838624 sha256=ecbcf2f2b7f1d51447db1b646c563c18005969ab48159b39ccdd63d818119cc3
#   Stored in directory: c:\users\administrator\appdata\local\pip\cache\wheels\37\2d\51\d2205756ed95e96ec350b55c1cf4ead47bab915a66151e9224
# Successfully built echarts-cities-pypkg
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install echarts-countries-pypkg
# Out:
# ...
#   Created wheel for echarts-countries-pypkg: filename=echarts_countries_pypkg-0.1.6-py3-none-any.whl size=2118070 sha256=6e8b7994680b005c53edc19048caf5e947cf79ce1410adec6a829715e76bac3c
#   Stored in directory: c:\users\administrator\appdata\local\pip\cache\wheels\7d\7f\dd\a3148436c212e0a6fad67684da836d98e26a3fdf40761d8eea
# Successfully built echarts-countries-pypkg
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install echarts-china-provinces-pypkg
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install echarts-china-cities-pypkg
# Out:
# ...
#   Running setup.py clean for echarts-china-cities-pypkg
# Failed to build echarts-china-cities-pypkg
# ...
#     Running setup.py install for echarts-china-cities-pypkg: started
#     Running setup.py install for echarts-china-cities-pypkg: finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
# ...

# %%
geo = Geo(
    "全国主要城市空气质量",
    "data from pm2.5",
    title_color="#fff",
    title_pos="center",
    width=1200,
    height=600,
    background_color="#404a59",
)
attr, value = geo.cast(data)
geo.add(
    "",
    attr,
    value,
    visual_range=[0, 200],
    visual_text_color="#fff",
    symbol_size=15,
    is_visualmap=True,
    is_piecewise=True,
    visual_split_number=6,
)
geo.render()

# %%
from pyecharts import options as opts
from pyecharts.charts import Map

# 数据
data = [
    ('山东省', 2938.9),
    ('广西壮族自治区', 2785.7),
    ('河南省', 2563.4),
    ('陕西省', 2070.6),
    ('广东省', 1882.6),
    ('新疆维吾尔自治区', 1660.4),
    ('河北省', 1424.4),
    ('四川省', 1221.3),
    ('湖南省', 1150.8),
    ('湖北省', 1066.8),
    ('江苏省', 974.2),
    ('云南省', 961.6),
    ('山西省', 909.8),
    ('辽宁省', 851.3),
    ('甘肃省', 779),
    ('福建省', 764.6),
    ('浙江省', 755.3),
    ('安徽省', 741.5),
    ('江西省', 712.8),
    ('贵州省', 548.1),
    ('重庆市', 514.8),
    ('海南省', 495.6),
    ('内蒙古自治区', 238.7),
    ('宁夏回族自治区', 204.5),
    ('黑龙江省', 170.1),
    ('吉林省', 146.6),
    ('天津市', 56.4),
    ('北京市', 53.8),
    ('上海市', 43.9),
    ('青海省', 2.9),
    ('西藏自治区', 2.2)
]

# 创建地图
c = (
    Map()
    .add("水果产量", data, "china", is_map_symbol_show=True)
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="全国主要省份水果产量"),
        visualmap_opts=opts.VisualMapOpts(
            max_=2938.9,
            min_=2.2,
        )
    )
    .render("test-0629.html")
)

# %%
from pyecharts import options as opts
from pyecharts.charts import Map, Geo, Page
from pyecharts.globals import ChartType
import os

# 数据
data = [
    ('山东省', 2938.9),
    ('广西壮族自治区', 2785.7),
    ('河南省', 2563.4),
    ('陕西省', 2070.6),
    ('广东省', 1882.6),
    ('新疆维吾尔自治区', 1660.4),
    ('河北省', 1424.4),
    ('四川省', 1221.3),
    ('湖南省', 1150.8),
    ('湖北省', 1066.8),
    ('江苏省', 974.2),
    ('云南省', 961.6),
    ('山西省', 909.8),
    ('辽宁省', 851.3),
    ('甘肃省', 779),
    ('福建省', 764.6),
    ('浙江省', 755.3),
    ('安徽省', 741.5),
    ('江西省', 712.8),
    ('贵州省', 548.1),
    ('重庆市', 514.8),
    ('海南省', 495.6),
    ('内蒙古自治区', 238.7),
    ('宁夏回族自治区', 204.5),
    ('黑龙江省', 170.1),
    ('吉林省', 146.6),
    ('天津市', 56.4),
    ('北京市', 53.8),
    ('上海市', 43.9),
    ('青海省', 2.9),
    ('西藏自治区', 2.2)
]

# 分离出前十的省份
top10 = sorted(data, key=lambda x: x[1], reverse=True)[:10]

# 创建地图
c = (
    Map()
    .add("水果产量", data, "china")
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="全国主要省份水果产量"),
        visualmap_opts=opts.VisualMapOpts(
            max_=2938.9,
            min_=2.2,
        )
    )
)

# 创建地理坐标图
geo = (
    Geo()
    .add_schema(maptype="china")
    .add(
        "前十的省份",
        top10,
        type_=ChartType.EFFECT_SCATTER,
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="全国主要省份水果产量"))
)

# 将两个图放在同一个页面
page = Page()
page.add(c, geo)
page.render("combined.html")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\annaconda\lib\site-packages\pyecharts\charts\basic_charts\geo.py in _feed_data(self, data_pair, type_)
#     216                 else:
# --> 217                     lng, lat = self.get_coordinate(n)
#     218                     result.append({"name": n, "value": [lng, lat, v]})
#
# TypeError: cannot unpack non-iterable NoneType object
#
# During handling of the above exception, another exception occurred:
#
# NonexistentCoordinatesException           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15220/486392797.py in <module>
#      58 # 创建地理坐标图
#      59 geo = (
# ---> 60     Geo()
#      61     .add_schema(maptype="china")
#      62     .add(
#
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Map

# 数据
data = [
    ('陕西省', 1185.2),
    ('山东省', 953.6),
    ('山西省', 436.6),
    ('河南省', 407.6),
    ('甘肃省', 386),
    ('辽宁省', 267.3),
    ('河北省', 239.7),
    ('新疆维吾尔自治区', 184),
    ('四川省', 80.8),
    ('云南省', 60.6),
]

# 创建地图
c = (
    Map()
    .add("产量", data, "china", is_map_symbol_show=True)
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="全国主要省份产量"),
        visualmap_opts=opts.VisualMapOpts(
            max_=1200,
            min_=0,
            is_piecewise=True,  # 设置是否为分段显示
            pieces=[
                {"min": 1000, "label": '>1000', "color": "#893448"},  # 不指定 max，表示 max 为无限大（Infinity）
                {"min": 500, "max": 1000, "label": '500-1000', "color": "#ff585e"},
                {"min": 100, "max": 500, "label": '100-500', "color": "#fb8146"},
                {"min": 0, "max": 100, "label": '0-100', "color": "#ffb248"},
                {"max": 0, "label": '无数据', "color": "#999"}  # 不指定 min，表示 min 为无限大（-Infinity）
            ]
        )
    )
    .render("apple_production_map.html")
)

# %%
from pyecharts import options as opts
from pyecharts.charts import Map

# 数据
data = [
    ('陕西省', 1185.2),
    ('山东省', 953.6),
    ('山西省', 436.6),
    ('河南省', 407.6),
    ('甘肃省', 386),
    ('辽宁省', 267.3),
    ('河北省', 239.7),
    ('新疆维吾尔自治区', 184),
    ('四川省', 80.8),
    ('云南省', 60.6),
]

# 创建地图
c = (
    Map()
    .add("产量", data, "china", is_map_symbol_show=False)
    .set_series_opts(label_opts=opts.LabelOpts(is_show=True))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="全国主要省份产量"),
        visualmap_opts=opts.VisualMapOpts(
            max_=1200,
            min_=0,
            is_piecewise=True,  # 设置是否为分段显示
            pieces=[
                {"min": 1000, "label": '>1000', "color": "#893448"},  # 不指定 max，表示 max 为无限大（Infinity）
                {"min": 500, "max": 1000, "label": '500-1000', "color": "#ff585e"},
                {"min": 100, "max": 500, "label": '100-500', "color": "#fb8146"},
                {"min": 0, "max": 100, "label": '0-100', "color": "#ffb248"},
                {"max": 0, "label": '无数据', "color": "#999"}  # 不指定 min，表示 min 为无限大（-Infinity）
            ]
        )
    )
    .render("apple_production_map.html")
)

# %%
from pyecharts import options as opts
from pyecharts.charts import Map

# 数据
data = [
    ('河北省', 143.9),
    ('辽宁省', 87.9),
    ('新疆维吾尔自治区', 71.3),
    ('河南省', 66.6),
    ('四川省', 66.6),
    ('云南省', 58.4),
    ('贵州省', 49.2),
    ('山西省', 46.7),
    ('陕西省', 44.5),
    ('安徽省', 41.2),
]

# 创建地图
c = (
    Map()
    .add("梨种植面积", data, "china", is_map_symbol_show=False)
    .set_series_opts(label_opts=opts.LabelOpts(is_show=True))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="全国主要省份梨种植面积（万公顷）"),
        visualmap_opts=opts.VisualMapOpts(
            max_=150,  # 对应最大面积数据143.9，设置稍大一些以保证色彩均衡
            min_=0,
            is_piecewise=True,  # 设置是否为分段显示
            pieces=[
                {"min": 100, "label": '>100', "color": "#893448"},  # 不指定 max，表示 max 为无限大（Infinity）
                {"min": 50, "max": 100, "label": '50-100', "color": "#ff585e"},
                {"min": 10, "max": 50, "label": '10-50', "color": "#fb8146"},
                {"min": 0, "max": 10, "label": '0-10', "color": "#ffb248"},
                {"max": 0, "label": '无数据', "color": "#999"}  # 不指定 min，表示 min 为无限大（-Infinity）
            ]
        )
    )
    .render("pear_planting_area_map.html")
)

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.globals import ChartType, SymbolType

c = (
    Geo()
    .add_schema(maptype="china")
    .add(
        "geo",
        [("河南省", "辽宁省"), ("湖北省", "云南省"), ("甘肃", "新疆")],
        type_=ChartType.LINES,
        effect_opts=opts.EffectOpts(symbol=SymbolType.ARROW, symbol_size=15, color="blue"),
        linestyle_opts=opts.LineStyleOpts(curve=0.4),
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="Geo-Lines"))
    .render("geo_lines.html")
)

# %%
from pyecharts import options as opts
from pyecharts.charts import Map

# 数据
data = [
    ('北京市', 2.06),
    ('天津市', 10.05),
    ('河北省', 118.79),
    ('山西省', 31.19),
    ('内蒙古自治区', 5.7),
    ('辽宁省', 78.24),
    ('吉林省', 8.9),
    ('黑龙江省', 5.42),
    ('上海市', 6.29),
    ('江苏省', 65.22),
    ('浙江省', 76.95),
    ('安徽省', 53.35),
    ('福建省', 21.84),
    ('江西省', 8.83),
    ('山东省', 112.48),
    ('河南省', 83.22),
    ('湖北省', 29.81),
    ('湖南省', 20.69),
    ('广东省', 0),
    ('广西壮族自治区', 60.13),
    ('海南省', 0),
    ('重庆市', 11.88),
    ('四川省', 40.65),
    ('贵州省', 31.97),
    ('云南省', 95.09),
    ('西藏自治区', 0.14),
    ('陕西省', 76.74),
    ('甘肃省', 26.18),
    ('青海省', 0.03),
    ('宁夏回族自治区', 24.54),
    ('新疆维吾尔自治区', 313.17),
]

# 创建地图
c = (
    Map()
    .add("葡萄产量", data, "china", is_map_symbol_show=False)
    .set_series_opts(label_opts=opts.LabelOpts(is_show=True))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="2019年中国各省份葡萄产量（万吨）"),
        visualmap_opts=opts.VisualMapOpts(
            max_=320,  # 对应最大产量数据313.17，设置稍大一些以保证色彩均衡
            min_=0,
            is_piecewise=True,  # 设置是否为分段显示
            pieces=[
                {"min": 100, "label": '>100', "color": "#893448"},  # 不指定 max，表示 max 为无限大（Infinity）
                {"min": 50, "max": 100, "label": '50-100', "color": "#ff585e"},
                {"min": 10, "max": 50, "label": '10-50', "color": "#fb8146"},
                {"min": 0, "max": 10, "label": '0-10', "color": "#ffb248"},
                {"max": 0, "label": '无数据', "color": "#999"}  # 不指定 min，表示 min 为无限大（-Infinity）
            ]
        )
    )
    .render("grape_production_map.html")
)
